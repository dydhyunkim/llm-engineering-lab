# %%
# !pip install -r ../requirements.txt
# Out:
# Requirement already satisfied: openai in /home/yhkim/llm-engineering-lab/.venv/lib/python3.10/site-packages (from -r ../requirements.txt (line 1)) (2.30.0)
# Requirement already satisfied: python-dotenv in /home/yhkim/llm-engineering-lab/.venv/lib/python3.10/site-packages (from -r ../requirements.txt (line 2)) (1.2.2)
# Requirement already satisfied: jiter<1,>=0.10.0 in /home/yhkim/llm-engineering-lab/.venv/lib/python3.10/site-packages (from openai->-r ../requirements.txt (line 1)) (0.13.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /home/yhkim/llm-engineering-lab/.venv/lib/python3.10/site-packages (from openai->-r ../requirements.txt (line 1)) (4.13.0)
# Requirement already satisfied: tqdm>4 in /home/yhkim/llm-engineering-lab/.venv/lib/python3.10/site-packages (from openai->-r ../requirements.txt (line 1)) (4.67.3)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/yhkim/llm-engineering-lab/.venv/lib/python3.10/site-packages (from openai->-r ../requirements.txt (line 1)) (0.28.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /home/yhkim/llm-engineering-lab/.venv/lib/python3.10/site-packages (from openai->-r ../requirements.txt (line 1)) (4.15.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /home/yhkim/llm-engineering-lab/.venv/lib/python3.10/site-packages (from openai->-r ../requirements.txt (line 1)) (1.9.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /home/yhkim/llm-engineering-lab/.venv/lib/python3.10/site-packages (from openai->-r ../requirements.txt (line 1)) (2.12.5)
# Requirement already satisfied: sniffio in /home/yhkim/llm-engineering-lab/.venv/lib/python3.10/site-packages (from openai->-r ../requirements.txt (line 1)) (1.3.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/yhkim/llm-engineering-lab/.venv/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai->-r ../requirements.txt (line 1)) (1.3.1)
# Requirement already satisfied: idna>=2.8 in /home/yhkim/llm-engineering-lab/.venv/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai->-r ../requirements.txt (line 1)) (3.11)
# Requirement already satisfied: certifi in /home/yhkim/llm-engineering-lab/.venv/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai->-r ../requirements.txt (line 1)) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /home/yhkim/llm-engineering-lab/.venv/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai->-r ../requirements.txt (line 1)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /home/yhkim/llm-engineering-lab/.venv/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai->-r ../requirements.txt (line 1)) (0.16.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /home/yhkim/llm-engineering-lab/.venv/lib/python3.10/site-packages (from pydantic<3,>=1.9.0->openai->-r ../requirements.txt (line 1)) (2.41.5)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/yhkim/llm-engineering-lab/.venv/lib/python3.10/site-packages (from pydantic<3,>=1.9.0->openai->-r ../requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/yhkim/llm-engineering-lab/.venv/lib/python3.10/site-packages (from pydantic<3,>=1.9.0->openai->-r ../requirements.txt (line 1)) (0.4.2)

# %%
import os
from openai import OpenAI
from dotenv import load_dotenv

load_dotenv()

client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

response = client.responses.create(
    model="gpt-4.1-mini",
    input="안녕하세요, AI와 첫 대화입니다. 환영해주세요."
)
print(response.output_text)

# response = client.chat.completions.create(
#     model="gpt-4.1-mini",
#     messages=[
#         {"role": "user", "content": "안녕하세요!"}
#     ]
# )
print(response.choices[0].message.content)
# Out:
# 안녕하세요! AI와의 첫 대화에 오신 것을 진심으로 환영합니다. 앞으로 함께 즐거운 대화 나눠요. 궁금한 점이나 이야기하고 싶은 주제가 있으면 언제든지 말씀해 주세요! 😊

# %% [markdown]
# 기존에 Open AI와의 대화를 하기 위해서는 completion 방식을 사용했지만 현재 OpenAI는 Responses 중심으로 대화하는 것을 권장하고 있다.
